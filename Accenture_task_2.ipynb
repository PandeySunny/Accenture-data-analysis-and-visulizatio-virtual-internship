# %%
-import pandas as pd

# %%
reaction_df=pd.read_csv("C:\\Users\pandeysunny2315\Downloads\Reactions.csv")
reactiontype_df=pd.read_csv("C:\\Users\pandeysunny2315\Downloads\ReactionTypes.csv")
content_df=pd.read_csv("C:\\Users\pandeysunny2315\Downloads\Content.csv")

# %%
reaction_df.head()
# Out:
#    Unnamed: 0                            Content ID  \
# 0           0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1           1  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2           2  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3           3  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4           4  97522e57-d9ab-4bd6-97bf-c24d952602d2
#
#                                 User ID     Type             Datetime
# 0                                   NaN      NaN  2021-04-22 15:17:15
# 1  5d454588-283d-459d-915d-c48a2cb4c27f  disgust  2020-11-07 09:43:50
# 2  92b87fa5-f271-43e0-af66-84fac21052e6  dislike  2021-06-17 12:22:51
# 3  163daa38-8b77-48c9-9af6-37a6c1447ac2   scared  2021-04-18 05:13:58
# 4  34e8add9-0206-47fd-a501-037b994650a2  disgust  2021-01-06 19:13:01

# %%
reactiontype_df.head()
# Out:
#    Unnamed: 0        Type Sentiment  Score
# 0           0       heart  positive     60
# 1           1        want  positive     70
# 2           2     disgust  negative      0
# 3           3        hate  negative      5
# 4           4  interested  positive     30

# %%
content_df.head()
# Out:
#    Unnamed: 0                            Content ID  \
# 0           0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1           1  9f737e0a-3cdd-4d29-9d24-753f4e3be810
# 2           2  230c4e4d-70c3-461d-b42c-ec09396efb3f
# 3           3  356fff80-da4d-4785-9f43-bc1261031dc6
# 4           4  01ab84dd-6364-4236-abbb-3f237db77180
#
#                                 User ID   Type        Category  \
# 0  8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo        Studying
# 1  beb1f34e-7870-46d6-9fc7-2e12eb83ce43  photo  healthy eating
# 2  a5c65404-5894-4b87-82f2-d787cbee86b4  photo  healthy eating
# 3  9fb4ce88-fac1-406c-8544-1a899cee7aaf  photo      technology
# 4  e206e31b-5f85-4964-b6ea-d7ee5324def1  video            food
#
#                                                  URL
# 0  https://socialbuzz.cdn.com/content/storage/975...
# 1  https://socialbuzz.cdn.com/content/storage/9f7...
# 2  https://socialbuzz.cdn.com/content/storage/230...
# 3  https://socialbuzz.cdn.com/content/storage/356...
# ...

# %%
reaction_df.isnull().sum()
# Out:
# Unnamed: 0       0
# Content ID       0
# User ID       3019
# Type           980
# Datetime         0
# dtype: int64

# %%
reactiontype_df.isnull().sum()
# Out:
# Unnamed: 0    0
# Type          0
# Sentiment     0
# Score         0
# dtype: int64

# %%
content_df.isnull().sum()
# Out:
# Unnamed: 0      0
# Content ID      0
# User ID         0
# Type            0
# Category        0
# URL           199
# dtype: int64

# %%
[[reaction_df.shape],[reactiontype_df.shape],[content_df.shape]]
# Out:
# [[(25553, 5)], [(16, 4)], [(1000, 6)]]

# %%
reactions_df = reaction_df.dropna()

# %% [markdown]
# # reaction_df having null values

# %%
reaction_df.shape
# Out:
# (25553, 5)

# %% [markdown]
# # reactions_df dont have any null values

# %%
reactions_df.shape
# Out:
# (22534, 5)

# %%
contents_df = content_df.dropna()

# %% [markdown]
# # content_df having some null values

# %%
content_df.shape
# Out:
# (1000, 6)

# %% [markdown]
# # contents_df don't have any null values

# %%
contents_df.shape
# Out:
# (801, 6)

# %%
reactions_df1= reactions_df.drop(columns= ["User ID"])

# %%
reactions_df1.head()
# Out:
#    Unnamed: 0                            Content ID        Type  \
# 1           1  97522e57-d9ab-4bd6-97bf-c24d952602d2     disgust
# 2           2  97522e57-d9ab-4bd6-97bf-c24d952602d2     dislike
# 3           3  97522e57-d9ab-4bd6-97bf-c24d952602d2      scared
# 4           4  97522e57-d9ab-4bd6-97bf-c24d952602d2     disgust
# 5           5  97522e57-d9ab-4bd6-97bf-c24d952602d2  interested
#
#               Datetime
# 1  2020-11-07 09:43:50
# 2  2021-06-17 12:22:51
# 3  2021-04-18 05:13:58
# 4  2021-01-06 19:13:01
# 5  2020-08-23 12:25:58

# %%
#reactions_df2=reactions_df1.drop(columns = ["Unnamed: 0"])
reactions_df2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[135], line 2
#       1 #reactions_df2=reactions_df1.drop(columns = ["Unnamed: 0"])
# ----> 2 reactions_df2
#
# NameError: name 'reactions_df2' is not defined

# %%
reactions_df2.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[134], line 1
# ----> 1 reactions_df2.head()
#
# NameError: name 'reactions_df2' is not defined

# %%
#contents_df2 = contents_df.drop(columns=["Unnamed: 0"])
contents_df1
# Out:
#                                Content ID   Type        Category  \
# 0    97522e57-d9ab-4bd6-97bf-c24d952602d2  photo        Studying
# 1    9f737e0a-3cdd-4d29-9d24-753f4e3be810  photo  healthy eating
# 2    230c4e4d-70c3-461d-b42c-ec09396efb3f  photo  healthy eating
# 3    356fff80-da4d-4785-9f43-bc1261031dc6  photo      technology
# 4    01ab84dd-6364-4236-abbb-3f237db77180  video            food
# ..                                    ...    ...             ...
# 994  c54b49c4-b1f2-4641-8595-1cbd19937845  photo         science
# 996  7a79f4e4-3b7d-44dc-bdef-bc990740252c    GIF      technology
# 997  435007a5-6261-4d8b-b0a4-55fdc189754b  audio        veganism
# 998  4e4c9690-c013-4ee7-9e66-943d8cbd27b7    GIF         culture
# 999  75d6b589-7fae-4a6d-b0d0-752845150e56  audio      technology
#
#                                                    URL
# 0    https://socialbuzz.cdn.com/content/storage/975...
# 1    https://socialbuzz.cdn.com/content/storage/9f7...
# ...

# %% [markdown]
# # User Id is already droped thats why it shows error

# %%
contents_df1 = contents_df.drop(columns=["User ID"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[115], line 1
# ----> 1 contents_df1 = contents_df.drop(columns=["User ID"])
#
# AttributeError: 'function' object has no attribute 'drop'

# %%
contents_df1.head()
# Out:
#    Unnamed: 0                            Content ID   Type        Category  \
# 0           0  97522e57-d9ab-4bd6-97bf-c24d952602d2  photo        Studying
# 1           1  9f737e0a-3cdd-4d29-9d24-753f4e3be810  photo  healthy eating
# 2           2  230c4e4d-70c3-461d-b42c-ec09396efb3f  photo  healthy eating
# 3           3  356fff80-da4d-4785-9f43-bc1261031dc6  photo      technology
# 4           4  01ab84dd-6364-4236-abbb-3f237db77180  video            food
#
#                                                  URL
# 0  https://socialbuzz.cdn.com/content/storage/975...
# 1  https://socialbuzz.cdn.com/content/storage/9f7...
# 2  https://socialbuzz.cdn.com/content/storage/230...
# 3  https://socialbuzz.cdn.com/content/storage/356...
# 4  https://socialbuzz.cdn.com/content/storage/01a...

# %% [markdown]
# # merging values by removing quote in contents_df1

# %%
contents_df1=contents_df["Category"].unique

# %%
contents_df1["Category"].value_counts()
# Out:
# Category
# travel             60
# science            55
# fitness            54
# animals            54
# culture            54
# technology         54
# tennis             53
# cooking            51
# healthy eating     50
# dogs               49
# education          48
# soccer             47
# food               47
# veganism           43
# studying           41
# public speaking    40
# Studying            1
# Name: count, dtype: int64

# %%
contents_df1
# Out:
#                                Content ID   Type        Category  \
# 0    97522e57-d9ab-4bd6-97bf-c24d952602d2  photo        Studying
# 1    9f737e0a-3cdd-4d29-9d24-753f4e3be810  photo  healthy eating
# 2    230c4e4d-70c3-461d-b42c-ec09396efb3f  photo  healthy eating
# 3    356fff80-da4d-4785-9f43-bc1261031dc6  photo      technology
# 4    01ab84dd-6364-4236-abbb-3f237db77180  video            food
# ..                                    ...    ...             ...
# 994  c54b49c4-b1f2-4641-8595-1cbd19937845  photo         science
# 996  7a79f4e4-3b7d-44dc-bdef-bc990740252c    GIF      technology
# 997  435007a5-6261-4d8b-b0a4-55fdc189754b  audio        veganism
# 998  4e4c9690-c013-4ee7-9e66-943d8cbd27b7    GIF         culture
# 999  75d6b589-7fae-4a6d-b0d0-752845150e56  audio      technology
#
#                                                    URL
# 0    https://socialbuzz.cdn.com/content/storage/975...
# 1    https://socialbuzz.cdn.com/content/storage/9f7...
# ...

# %%
reaction_content_merging = pd.merge(reactions_df1, contents_df1, on=["Content ID"], how="inner")

# %%
reaction_content_merging.head()
# Out:
#                              Content ID                               User ID  \
# 0  97522e57-d9ab-4bd6-97bf-c24d952602d2  5d454588-283d-459d-915d-c48a2cb4c27f
# 1  97522e57-d9ab-4bd6-97bf-c24d952602d2  92b87fa5-f271-43e0-af66-84fac21052e6
# 2  97522e57-d9ab-4bd6-97bf-c24d952602d2  163daa38-8b77-48c9-9af6-37a6c1447ac2
# 3  97522e57-d9ab-4bd6-97bf-c24d952602d2  34e8add9-0206-47fd-a501-037b994650a2
# 4  97522e57-d9ab-4bd6-97bf-c24d952602d2  9b6d35f9-5e15-4cd0-a8d7-b1f3340e02c4
#
#        Type_x             Datetime Type_y  Category  \
# 0     disgust  2020-11-07 09:43:50  photo  Studying
# 1     dislike  2021-06-17 12:22:51  photo  Studying
# 2      scared  2021-04-18 05:13:58  photo  Studying
# 3     disgust  2021-01-06 19:13:01  photo  Studying
# 4  interested  2020-08-23 12:25:58  photo  Studying
#
#                                                  URL
# 0  https://socialbuzz.cdn.com/content/storage/975...
# 1  https://socialbuzz.cdn.com/content/storage/975...
# ...

# %%
reaction_content_merging=reaction_content_merging.drop(columns=["User ID"])

# %%
reaction_content_merging
# Out:
#                                  Content ID      Type_x             Datetime  \
# 0      97522e57-d9ab-4bd6-97bf-c24d952602d2     disgust  2020-11-07 09:43:50
# 1      97522e57-d9ab-4bd6-97bf-c24d952602d2     dislike  2021-06-17 12:22:51
# 2      97522e57-d9ab-4bd6-97bf-c24d952602d2      scared  2021-04-18 05:13:58
# 3      97522e57-d9ab-4bd6-97bf-c24d952602d2     disgust  2021-01-06 19:13:01
# 4      97522e57-d9ab-4bd6-97bf-c24d952602d2  interested  2020-08-23 12:25:58
# ...                                     ...         ...                  ...
# 18379  75d6b589-7fae-4a6d-b0d0-752845150e56     worried  2020-10-31 04:50:14
# 18380  75d6b589-7fae-4a6d-b0d0-752845150e56     dislike  2020-06-27 09:46:48
# 18381  75d6b589-7fae-4a6d-b0d0-752845150e56   intrigued  2021-02-16 17:17:02
# 18382  75d6b589-7fae-4a6d-b0d0-752845150e56     worried  2020-11-04 20:08:31
# 18383  75d6b589-7fae-4a6d-b0d0-752845150e56     cherish  2021-01-04 04:55:11
#
# ...

# %%
reactiontype_df = reactiontype_df.drop(columns=["Unnamed: 0"])

# %%
reactiontype_df
# Out:
#            Type Sentiment  Score
# 0         heart  positive     60
# 1          want  positive     70
# 2       disgust  negative      0
# 3          hate  negative      5
# 4    interested  positive     30
# 5   indifferent   neutral     20
# 6          love  positive     65
# 7    super love  positive     75
# 8       cherish  positive     70
# 9         adore  positive     72
# 10         like  positive     50
# 11      dislike  negative     10
# 12    intrigued  positive     45
# 13      peeking   neutral     35
# 14       scared  negative     15
# 15      worried  negative     12

# %%
reactiontype_df['key']=reactiontype_df.index

# %%
reaction_content_merging['key']=reaction_content_merging.index

# %%
[reactiontype_df.head(),reaction_content_merging.head()]
# Out:
# [         Type Sentiment  Score  Key
#  0       heart  positive     60    0
#  1        want  positive     70    1
#  2     disgust  negative      0    2
#  3        hate  negative      5    3
#  4  interested  positive     30    4,
#                               Content ID      Type_x             Datetime  \
#  0  97522e57-d9ab-4bd6-97bf-c24d952602d2     disgust  2020-11-07 09:43:50
#  1  97522e57-d9ab-4bd6-97bf-c24d952602d2     dislike  2021-06-17 12:22:51
#  2  97522e57-d9ab-4bd6-97bf-c24d952602d2      scared  2021-04-18 05:13:58
#  3  97522e57-d9ab-4bd6-97bf-c24d952602d2     disgust  2021-01-06 19:13:01
#  4  97522e57-d9ab-4bd6-97bf-c24d952602d2  interested  2020-08-23 12:25:58
#
#    Type_y  Category                                                URL  key
#  0  photo  Studying  https://socialbuzz.cdn.com/content/storage/975...    0
#  1  photo  Studying  https://socialbuzz.cdn.com/content/storage/975...    1
# ...

# %%
reactiontype_df=reactiontype_df.drop(columns=['Key'])

# %%
merged_df1=pd.merge(reaction_content_merging, reactiontype_df, on=['key'], how='outer')

# %%
content_merged_df1 = merged_df1.rename(columns = {'Type_x':'Reaction mood', 'Type_y':'Content Type', 'Type':'Reaction Type'}, inplace=True)

# %%
content_merged_df1

# %%
merged_df1
# Out:
#                                  Content ID Reaction mood  \
# 0      97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust
# 1      97522e57-d9ab-4bd6-97bf-c24d952602d2       dislike
# 2      97522e57-d9ab-4bd6-97bf-c24d952602d2        scared
# 3      97522e57-d9ab-4bd6-97bf-c24d952602d2       disgust
# 4      97522e57-d9ab-4bd6-97bf-c24d952602d2    interested
# ...                                     ...           ...
# 18379  75d6b589-7fae-4a6d-b0d0-752845150e56       worried
# 18380  75d6b589-7fae-4a6d-b0d0-752845150e56       dislike
# 18381  75d6b589-7fae-4a6d-b0d0-752845150e56     intrigued
# 18382  75d6b589-7fae-4a6d-b0d0-752845150e56       worried
# 18383  75d6b589-7fae-4a6d-b0d0-752845150e56       cherish
#
#                   Datetime Content Type    Category  \
# 0      2020-11-07 09:43:50        photo    Studying
# 1      2021-06-17 12:22:51        photo    Studying
# 2      2021-04-18 05:13:58        photo    Studying
# 3      2021-01-06 19:13:01        photo    Studying
# ...
